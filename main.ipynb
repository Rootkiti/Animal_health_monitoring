# %%
import pandas as pd

# %%
data = pd.read_excel('sample-pig-diseases.xlsx')
data
# Out:
#    Animal                                            Disease  \
# 0     pig                                        Brucellosis
# 1     pig                            Foot and Mouth\nDisease
# 2     pig                         Vesicular Stomatitis\n(VS)
# 3     pig                                      Leptospirosis
# 4     pig                                             Rabies
# 5     pig                                           Ringworm
# 6     pig                              Classical Swine Fever
# 7     pig                                      Edema Disease
# 8     pig                Swine Dysentery\n(Bloody Dysentery)
# 9     pig                                         Mycoplasma
# 10    pig           Porcine\nPleuropneumonia\n(formally HPP)
# 11    pig                                 Pseudorabies (PRV)
# 12    pig                          Porcine Parvovirus\n(PPV)
# 13    pig                                African Swine Fever
# ...
